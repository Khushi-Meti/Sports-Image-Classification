# %% [markdown]
# <h2 style='color:blue' align='center'>Sports Celebrity Image Classification<h2>

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h3 style='color:purple'>(1) Preprocessing: Detect face and eyes</h3>

# %% [markdown]
# #### When we look at any image, most of the time we identify a person using a face. An image might contain multiple faces, also the face can be obstructed and not clear. The first step in our pre-processing pipeline is to detect faces from an image. Once face is detected, we will detect eyes, if two eyes are detected then only we keep that image otherwise discard it.</h4>

# %% [markdown]
# #### Now how do you detect face and eyes?

# %% [markdown]
# We will use haar cascade from opencv for this. Here is an article on this: https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_objdetect/py_face_detection/py_face_detection.html?highlight=haar

# %%
img = cv2.imread(r'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/lionel_messi/abc.jpg')
img.shape
# Out:
# (422, 634, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (422, 634)

# %%
gray
# Out:
# array([[ 36,  40,  42, ...,  79,  79,  79],
#        [ 36,  39,  42, ...,  79,  81,  81],
#        [ 36,  39,  41, ...,  79,  80,  80],
#        ...,
#        [127, 127, 129, ..., 130, 137, 137],
#        [133, 132, 132, ..., 129, 135, 135],
#        [134, 136, 139, ..., 128, 130, 130]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[318,  31, 111, 111]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (318, 31, 111, 111)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %% [markdown]
# <h3 style='color:purple'>(2) Preprocessing: Crop the facial region of the image</h3>

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (111, 111, 3)

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Use wavelet transform as a feature for traning our model</h3>

# %% [markdown]
# #### In wavelet transformed image, you can see edges clearly and that can give us clues on various facial features such as eyes, nose, lips etc

# %% [markdown]
# ### Wavelet transform

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %% [markdown]
# #### You can see above a wavelet transformed image that gives clues on facial features such as eyes, nose, lips etc. This along with raw pixel image can be used as an input for our classifier

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Load image, detect face. If eyes >=2, then save and crop the face region</h3>

# %% [markdown]
# ####  Lets write a python function that can take input image and returns cropped image (if face and eyes >=2 are detected)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread(r'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/lionel_messi/abc.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes(r'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/lionel_messi/abc.jpg')
plt.imshow(cropped_image)

# %% [markdown]
# **In below image face is not very clear and it doesn't have two eyes clearly visible**

# %%
org_image_obstructed = cv2.imread(r'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/lionel_messi/messi.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes(r'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/lionel_messi/messi.jpg')
cropped_image_no_2_eyes
# Out:
# array([[[ 52,  46,  33],
#         [ 52,  46,  33],
#         [ 51,  45,  32],
#         ...,
#         [  0,   3,   4],
#         [ 13,  18,  19],
#         [ 12,  17,  18]],
#
#        [[ 50,  44,  31],
#         [ 50,  44,  31],
#         [ 48,  42,  29],
#         ...,
#         [ 50,  55,  56],
#         [ 30,  35,  36],
#         [  5,  10,  11]],
#
#        [[ 52,  46,  33],
#         [ 52,  46,  33],
#         [ 52,  46,  33],
#         ...,
#         [ 78,  83,  84],
#         [ 52,  57,  58],
#         [ 22,  27,  28]],
#
#        ...,
#
#        [[192, 188, 183],
#         [193, 189, 184],
#         [195, 191, 186],
#         ...,
#         [152, 191, 236],
#         [108, 149, 198],
#         [ 79, 124, 175]],
#
#        [[191, 187, 182],
#         [192, 188, 183],
#         [194, 190, 185],
#         ...,
#         [133, 175, 218],
#         [118, 164, 211],
#         [ 96, 145, 195]],
#
#        [[191, 187, 182],
#         [192, 188, 183],
#         [194, 190, 185],
#         ...,
#         [111, 152, 197],
#         [128, 176, 224],
#         [110, 163, 213]]], dtype=uint8)

# %% [markdown]
# **Above cropped_image_no_2_eyes is None which means we should ignore this image and we will not use such image for model training**

# %%
path_to_data = "C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/"
path_to_cr_data = "C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdata"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/.ipynb_checkpoints',
#  'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdata',
#  'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatalionel_messi',
#  'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatamaria_sharapova',
#  'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdataroger_federer',
#  'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdataserena_williams',
#  'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdataVirat_Kohli',
#  'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/lionel_messi',
#  'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/maria_sharapova',
#  'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/roger_federer',
#  'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/serena_williams',
#  'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/Virat_Kohli']

# %% [markdown]
# **Go through all images in dataset folder and create cropped images for them. There will be cropped folder inside dataset folder after you run this code**

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
import cv2
import os

def get_cropped_image_if_2_eyes(image_path):
    # Assuming this function reads the image and returns a cropped image if two eyes are detected
    img = cv2.imread(image_path)
    
    if img is None:
        print(f"Warning: Image at {image_path} could not be loaded.")
        return None
    
    # Add your eye detection and cropping logic here
    # Let's assume it returns None if the eyes are not detected or the image is not valid
    # roi_color = <cropped_image_if_2_eyes_logic>
    # return roi_color
    
    # Temporary placeholder for debugging
    return img  # For testing, return the full image

cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(f"Processing images for {celebrity_name}...")

    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print(f"Generating cropped images in folder: {cropped_folder}")
                
            cropped_file_name = f"{celebrity_name}{count}.png"
            cropped_file_path = os.path.join(cropped_folder, cropped_file_name)
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
        else:
            print(f"Skipping {entry.path} as it does not contain a valid cropped image.")
# Out:
# Processing images for .ipynb_checkpoints...
# Processing images for cropdata...
# Processing images for cropdatalionel_messi...
# Generating cropped images in folder: C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi
# Processing images for cropdatamaria_sharapova...
# Generating cropped images in folder: C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova
# Processing images for cropdataroger_federer...
# Generating cropped images in folder: C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer
# Processing images for cropdataserena_williams...
# Generating cropped images in folder: C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams
# Processing images for cropdataVirat_Kohli...
# Generating cropped images in folder: C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataVirat_Kohli
# Processing images for lionel_messi...
# Warning: Image at C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/lionel_messi\.ipynb_checkpoints could not be loaded.
# Skipping C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/lionel_messi\.ipynb_checkpoints as it does not contain a valid cropped image.
# Processing images for maria_sharapova...
# Processing images for roger_federer...
# Processing images for serena_williams...
# Processing images for Virat_Kohli...

# %% [markdown]
# ### Now you should have cropped folder under datasets folder that contains cropped images

# %% [markdown]
# ### Manually examine cropped folder and delete any unwanted images

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'cropdatacropdatalionel_messi': ['C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi1.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi10.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi11.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi12.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi13.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi14.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi15.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi16.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi17.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi18.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi19.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi2.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi20.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi21.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi22.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi23.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi24.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi25.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi26.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi27.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi28.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi29.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi3.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi30.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi31.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi32.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi33.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi34.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi35.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi36.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi37.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi38.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi39.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi4.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi40.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi41.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi42.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi43.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi44.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi45.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi46.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi47.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi48.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi49.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi5.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi50.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi51.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi52.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi53.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi54.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi55.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi56.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi57.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi58.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi59.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi6.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi7.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi8.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatalionel_messi\\cropdatalionel_messi9.png'],
#  'cropdatacropdatamaria_sharapova': ['C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova1.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova10.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova11.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova12.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova13.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova14.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova15.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova16.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova17.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova18.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova19.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova2.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova20.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova21.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova22.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova23.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova24.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova25.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova26.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova27.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova28.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova29.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova3.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova30.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova31.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova32.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova33.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova34.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova35.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova36.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova37.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova38.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova39.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova4.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova40.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova41.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova42.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova43.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova44.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova45.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova46.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova47.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova48.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova49.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova5.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova50.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova51.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova52.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova53.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova54.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova55.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova56.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova57.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova58.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova59.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova6.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova60.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova61.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova62.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova63.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova64.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova65.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova66.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova67.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova68.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova69.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova7.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova70.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova71.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova72.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova73.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova74.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova75.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova76.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova77.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova8.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdatamaria_sharapova\\cropdatamaria_sharapova9.png'],
#  'cropdatacropdataroger_federer': ['C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer1.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer10.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer11.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer12.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer13.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer14.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer15.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer16.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer17.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer18.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer19.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer2.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer20.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer21.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer22.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer23.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer24.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer25.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer26.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer27.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer28.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer29.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer3.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer30.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer31.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer32.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer33.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer34.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer35.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer36.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer37.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer38.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer39.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer4.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer40.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer41.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer42.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer43.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer44.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer45.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer46.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer47.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer48.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer49.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer5.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer50.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer51.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer52.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer53.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer54.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer55.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer56.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer57.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer58.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer59.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer6.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer60.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer61.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer7.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer8.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataroger_federer\\cropdataroger_federer9.png'],
#  'cropdatacropdataserena_williams': ['C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams1.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams10.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams11.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams12.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams13.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams14.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams15.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams16.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams17.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams18.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams19.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams2.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams20.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams21.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams22.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams23.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams24.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams25.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams26.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams27.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams28.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams29.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams3.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams30.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams31.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams32.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams33.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams34.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams35.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams36.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams37.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams38.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams39.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams4.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams40.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams41.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams42.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams43.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams44.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams45.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams46.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams47.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams48.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams49.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams5.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams50.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams51.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams52.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams53.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams54.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams55.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams56.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams57.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams58.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams59.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams6.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams60.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams61.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams62.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams63.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams64.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams65.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams66.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams67.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams68.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams7.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams8.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataserena_williams\\cropdataserena_williams9.png'],
#  'cropdatacropdataVirat_Kohli': ['C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataVirat_Kohli\\cropdataVirat_Kohli1.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataVirat_Kohli\\cropdataVirat_Kohli10.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataVirat_Kohli\\cropdataVirat_Kohli11.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataVirat_Kohli\\cropdataVirat_Kohli12.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataVirat_Kohli\\cropdataVirat_Kohli13.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataVirat_Kohli\\cropdataVirat_Kohli14.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataVirat_Kohli\\cropdataVirat_Kohli15.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataVirat_Kohli\\cropdataVirat_Kohli16.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataVirat_Kohli\\cropdataVirat_Kohli2.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataVirat_Kohli\\cropdataVirat_Kohli3.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataVirat_Kohli\\cropdataVirat_Kohli4.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataVirat_Kohli\\cropdataVirat_Kohli5.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataVirat_Kohli\\cropdataVirat_Kohli6.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataVirat_Kohli\\cropdataVirat_Kohli7.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataVirat_Kohli\\cropdataVirat_Kohli8.png',
#   'C:/Users/khush/OneDrive/Desktop/Data Science Projects/Sports celebrity image classification/model/image dataset/cropdatacropdataVirat_Kohli\\cropdataVirat_Kohli9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'cropdatacropdatalionel_messi': 0,
#  'cropdatacropdatamaria_sharapova': 1,
#  'cropdatacropdataroger_federer': 2,
#  'cropdatacropdataserena_williams': 3,
#  'cropdatacropdataVirat_Kohli': 4}

# %% [markdown]
# ### Images in cropped folder can be used for model training. We will use these raw images along with wavelet transformed images to train our classifier. Let's prepare X and y now

# %%
import cv2
import numpy as np

# Assume class_dict and w2d are defined earlier in your code
X, y = [], []

for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        
        if img is None:
            print(f"Warning: Image {training_image} could not be loaded.")
            continue
        
        # Resize the raw image to (32, 32)
        scalled_raw_img = cv2.resize(img, (32, 32))
        
        # Generate the Haar wavelet transformed image
        img_har = w2d(img, 'db1', 5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        
        # Combine the raw image and the Haar image into one feature vector
        combined_img = np.vstack((
            scalled_raw_img.reshape(32*32*3, 1), 
            scalled_img_har.reshape(32*32, 1)
        ))
        
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# Convert X and y to numpy arrays for use in machine learning models
X = np.array(X).reshape(len(X), -1)
y = np.array(y)

print(f"Feature matrix shape: {X.shape}")
print(f"Labels shape: {y.shape}")
# Out:
# Feature matrix shape: (281, 4096)
# Labels shape: (281,)

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[ 62],
#        [ 59],
#        [ 45],
#        ...,
#        [245],
#        [  1],
#        [255]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (281, 4096)

# %% [markdown]
# ### Data cleaning process is done. Now we are ready to train our model

# %% [markdown]
# We will use SVM with rbf kernel tuned  with heuristic finetuning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.4788732394366197

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.40      0.67      0.50        12
#            1       0.48      0.67      0.56        18
#            2       0.60      0.35      0.44        17
#            3       0.50      0.40      0.44        20
#            4       0.00      0.00      0.00         4
#
#     accuracy                           0.48        71
#    macro avg       0.40      0.42      0.39        71
# weighted avg       0.47      0.48      0.46        71
# C:\Users\khush\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\khush\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\khush\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ### Let's use GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.438095
# 1        random_forest    0.304762
# 2  logistic_regression    0.333333
#
#                                     best_params
# 0           {'svc__C': 1, 'svc__kernel': 'rbf'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc', SVC(C=1, gamma='auto', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.4788732394366197

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.4225352112676056

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.38028169014084506

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 8,  2,  1,  1,  0],
#        [ 2, 13,  1,  2,  0],
#        [ 1,  8,  7,  1,  0],
#        [ 6,  7,  1,  6,  0],
#        [ 3,  1,  0,  0,  0]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'cropdatacropdatalionel_messi': 0,
#  'cropdatacropdatamaria_sharapova': 1,
#  'cropdatacropdataroger_federer': 2,
#  'cropdatacropdataserena_williams': 3,
#  'cropdatacropdataVirat_Kohli': 4}

# %% [markdown]
# ### Save the trained model

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\khush\anaconda3\lib\site-packages (1.4.2)
# ['saved_model.pkl']

# %% [markdown]
# ### Save class dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
